# %%
import pandas as pd

uri = "https://gist.githubusercontent.com/guilhermesilveira/e99a526b2e7ccc6c3b70f53db43a87d2/raw/1605fc74aa778066bf2e6695e24d53cf65f2f447/machine-learning-carros-simulacao.csv"
dados = pd.read_csv(uri).drop(columns=["Unnamed: 0"], axis=1)
dados.head()
# Out:
#        preco  vendido  idade_do_modelo   km_por_ano
# 0   30941.02        1               18  35085.22134
# 1   40557.96        1               20  12622.05362
# 2   89627.50        0               12  11440.79806
# 3   95276.14        0                3  43167.32682
# 4  117384.68        1                4  12770.11290

# %%
# situação horrível de "azar" onde as classes estão ordenadas por padrão

dados_azar = dados.sort_values("vendido", ascending=True)
x_azar = dados_azar[["preco", "idade_do_modelo","km_por_ano"]]
y_azar = dados_azar["vendido"]
dados_azar.head()
# Out:
#          preco  vendido  idade_do_modelo   km_por_ano
# 4999  74023.29        0               12  24812.80412
# 5322  84843.49        0               13  23095.63834
# 5319  83100.27        0               19  36240.72746
# 5316  87932.13        0               16  32249.56426
# 5315  77937.01        0               15  28414.50704

# %%
from sklearn.model_selection import cross_validate
from sklearn.dummy import DummyClassifier
import numpy as np

SEED = 301
np.random.seed(SEED)

modelo = DummyClassifier()
results = cross_validate(modelo, x_azar, y_azar, cv = 10, return_train_score=False)
media = results['test_score'].mean()
desvio_padrao = results['test_score'].std()
print("Accuracy com dummy stratified, 10 = [%.2f, %.2f]" % ((media - 2 * desvio_padrao)*100, (media + 2 * desvio_padrao) * 100))
# Out:
# Accuracy com dummy stratified, 10 = [58.00, 58.00]

# %%
from sklearn.model_selection import cross_validate
from sklearn.tree import DecisionTreeClassifier

SEED = 301
np.random.seed(SEED)

modelo = DecisionTreeClassifier(max_depth=2)
results = cross_validate(modelo, x_azar, y_azar, cv = 10, return_train_score=False)
media = results['test_score'].mean()
desvio_padrao = results['test_score'].std()
print("Accuracy com cross validation, 10 = [%.2f, %.2f]" % ((media - 2 * desvio_padrao)*100, (media + 2 * desvio_padrao) * 100))
# Out:
# Accuracy com cross validation, 10 = [73.83, 77.73]

# %%
# gerando dados elatorios de modelo de carro para simulacao de agrupamento ao usar nosso estimador

np.random.seed(SEED)
dados['modelo'] = dados.idade_do_modelo + np.random.randint(-2, 3, size=10000)
dados.modelo = dados.modelo + abs(dados.modelo.min()) + 1
dados.head()
# Out:
#        preco  vendido  idade_do_modelo   km_por_ano  modelo
# 0   30941.02        1               18  35085.22134      18
# 1   40557.96        1               20  12622.05362      24
# 2   89627.50        0               12  11440.79806      14
# 3   95276.14        0                3  43167.32682       6
# 4  117384.68        1                4  12770.11290       5

# %%
def imprime_resultados(results):
  media = results['test_score'].mean() * 100
  desvio = results['test_score'].std() * 100
  print("Accuracy médio %.2f" % media)
  print("Intervalo [%.2f, %.2f]" % (media - 2 * desvio, media + 2 * desvio))

# %%
# GroupKFold para analisar como o modelo se comporta com novos grupos

from sklearn.model_selection import GroupKFold

SEED = 301
np.random.seed(SEED)

cv = GroupKFold(n_splits = 10)
modelo = DecisionTreeClassifier(max_depth=2)
results = cross_validate(modelo, x_azar, y_azar, cv = cv, groups = dados.modelo, return_train_score=False)
imprime_resultados(results)
# Out:
# Accuracy médio 75.78
# Intervalo [73.67, 77.90]

# %%
# GroupKFold em um pipeline com StandardScaler e SVC

from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline

SEED = 301
np.random.seed(SEED)

scaler = StandardScaler()
modelo = SVC()

pipeline = Pipeline([('transformacao',scaler), ('estimador',modelo)])

cv = GroupKFold(n_splits = 10)
results = cross_validate(pipeline, x_azar, y_azar, cv = cv, groups = dados.modelo, return_train_score=False)
imprime_resultados(results)
# Out:
# Accuracy médio 76.68
# Intervalo [74.28, 79.08]

# %%
# !pip install graphviz==0.9
# !pip install pydot
# !apt-get install graphviz
# !pip install seaborn==0.9.0
# Out:
# Collecting graphviz==0.9
#   Downloading graphviz-0.9-py2.py3-none-any.whl (16 kB)
# Installing collected packages: graphviz
#   Attempting uninstall: graphviz
#     Found existing installation: graphviz 0.20.3
#     Uninstalling graphviz-0.20.3:
#       Successfully uninstalled graphviz-0.20.3
# Successfully installed graphviz-0.9
# Requirement already satisfied: pydot in /usr/local/lib/python3.10/dist-packages (1.4.2)
# Requirement already satisfied: pyparsing>=2.1.4 in /usr/local/lib/python3.10/dist-packages (from pydot) (3.1.2)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# graphviz is already the newest version (2.42.2-6).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# Collecting seaborn==0.9.0
#   Downloading seaborn-0.9.0-py3-none-any.whl (208 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.1/208.1 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from seaborn==0.9.0) (3.7.1)
# Requirement already satisfied: numpy>=1.9.3 in /usr/local/lib/python3.10/dist-packages (from seaborn==0.9.0) (1.25.2)
# Requirement already satisfied: pandas>=0.15.2 in /usr/local/lib/python3.10/dist-packages (from seaborn==0.9.0) (2.0.3)
# Requirement already satisfied: scipy>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from seaborn==0.9.0) (1.11.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.3->seaborn==0.9.0) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.3->seaborn==0.9.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.3->seaborn==0.9.0) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.3->seaborn==0.9.0) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.3->seaborn==0.9.0) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.3->seaborn==0.9.0) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.3->seaborn==0.9.0) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.3->seaborn==0.9.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.15.2->seaborn==0.9.0) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.15.2->seaborn==0.9.0) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=1.4.3->seaborn==0.9.0) (1.16.0)
# Installing collected packages: seaborn
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.13.1
#     Uninstalling seaborn-0.13.1:
#       Successfully uninstalled seaborn-0.13.1
# Successfully installed seaborn-0.9.0

# %%
from sklearn.tree import export_graphviz
import graphviz

modelo.fit(x_azar, y_azar)
features = x_azar.columns
dot_data = export_graphviz(modelo, out_file=None, filled=True, rounded=True, class_names=["não", "sim"], feature_names = features)

graph = graphviz.Source(dot_data)
graph
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-710dcfae1f17> in <cell line: 6>()
#       4 modelo.fit(x_azar, y_azar)
#       5 features = x_azar.columns
# ----> 6 dot_data = export_graphviz(modelo, out_file=None, filled=True, rounded=True, class_names=["não", "sim"], feature_names = features)
#       7
#       8 graph = graphviz.Source(dot_data)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/tree/_export.py in export_graphviz(decision_tree, out_file, max_depth, feature_names, class_names, label, filled, leaves_parallel, impurity, node_ids, proportion, rotate, rounded, special_characters, precision, fontname)
#     886             fontname=fontname,
#     887         )
# --> 888         exporter.export(decision_tree)
#     889
#     890         if return_string:
#
# /usr/local/lib/python3.10/dist-packages/sklearn/tree/_export.py in export(self, decision_tree)
#     459             self.recurse(decision_tree, 0, criterion="impurity")
#     460         else:
# --> 461             self.recurse(decision_tree.tree_, 0, criterion=decision_tree.criterion)
#     462
#     463         self.tail()
#
# AttributeError: 'SVC' object has no attribute 'tree_'

# %%
from sklearn.model_selection import cross_validate
from sklearn.tree import DecisionTreeClassifier

SEED = 301
np.random.seed(SEED)

modelo = DecisionTreeClassifier(max_depth=3)
results = cross_validate(modelo, x_azar, y_azar, cv = 10, return_train_score=False)
media = results['test_score'].mean()
desvio_padrao = results['test_score'].std()
print("Accuracy com cross validation, 10 = [%.2f, %.2f]" % ((media - 2 * desvio_padrao)*100, (media + 2 * desvio_padrao) * 100))
# Out:
# Accuracy com cross validation, 10 = [75.87, 81.53]

# %%
from sklearn.tree import export_graphviz
import graphviz

modelo.fit(x_azar, y_azar)
features = x_azar.columns
dot_data = export_graphviz(modelo, out_file=None, filled=True, rounded=True, class_names=["não", "sim"], feature_names = features)

graph = graphviz.Source(dot_data)
graph

# %%
def roda_arvore_de_decisao(max_depth):
  SEED = 301
  np.random.seed(SEED)

  modelo = DecisionTreeClassifier(max_depth=max_depth)
  results = cross_validate(modelo, x_azar, y_azar, cv = 10, return_train_score=True)
  train_score = results['train_score'].mean() * 100
  test_score = results['test_score'].mean() * 100
  media = results['test_score'].mean()
  desvio_padrao = results['test_score'].std()
  #print("Accuracy com cross validation, 10 = [%.2f, %.2f]" % ((media - 2 * desvio_padrao)*100, (media + 2 * desvio_padrao) * 100))
  print("Arvore max_depth = %d, teste = %.2f, treino = %.2f" % (max_depth,test_score, train_score))
  tabela = [max_depth, train_score, test_score]
  return tabela


resultados = [roda_arvore_de_decisao(i) for i in range(1,33)]
resultados = pd.DataFrame(resultados, columns = ["max_depth", "teste", "treino"])
# Out:
# Arvore max_depth = 1, teste = 75.78, treino = 75.79
# Arvore max_depth = 2, teste = 75.78, treino = 75.79
# Arvore max_depth = 3, teste = 78.70, treino = 78.75
# Arvore max_depth = 4, teste = 78.63, treino = 78.80
# Arvore max_depth = 5, teste = 78.56, treino = 78.97
# Arvore max_depth = 6, teste = 78.49, treino = 79.19
# Arvore max_depth = 7, teste = 78.04, treino = 79.44
# Arvore max_depth = 8, teste = 77.83, treino = 79.81
# Arvore max_depth = 9, teste = 77.55, treino = 80.36
# Arvore max_depth = 10, teste = 77.03, treino = 80.99
# Arvore max_depth = 11, teste = 76.30, treino = 81.79
# Arvore max_depth = 12, teste = 76.15, treino = 82.64
# Arvore max_depth = 13, teste = 75.71, treino = 83.56
# Arvore max_depth = 14, teste = 75.40, treino = 84.56
# Arvore max_depth = 15, teste = 75.32, treino = 85.62
# Arvore max_depth = 16, teste = 75.09, treino = 86.75
# Arvore max_depth = 17, teste = 74.92, treino = 87.80
# Arvore max_depth = 18, teste = 74.82, treino = 88.81
# Arvore max_depth = 19, teste = 74.04, treino = 89.85
# Arvore max_depth = 20, teste = 74.15, treino = 90.84
# Arvore max_depth = 21, teste = 73.81, treino = 91.80
# Arvore max_depth = 22, teste = 73.92, treino = 92.70
# Arvore max_depth = 23, teste = 73.78, treino = 93.48
# Arvore max_depth = 24, teste = 73.48, treino = 94.27
# Arvore max_depth = 25, teste = 73.18, treino = 95.04
# Arvore max_depth = 26, teste = 72.99, treino = 95.73
# Arvore max_depth = 27, teste = 73.19, treino = 96.25
# Arvore max_depth = 28, teste = 72.78, treino = 96.84
# Arvore max_depth = 29, teste = 72.85, treino = 97.28
# Arvore max_depth = 30, teste = 72.33, treino = 97.65
# Arvore max_depth = 31, teste = 72.58, treino = 98.03
# Arvore max_depth = 32, teste = 72.42, treino = 98.26

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.lineplot(x = "max_depth", y = "treino",data = resultados)
sns.lineplot(x = "max_depth", y = "teste",data = resultados)
plt.legend(["Treino", "Teste"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-afeb059e9c3f> in <cell line: 4>()
#       2 import matplotlib.pyplot as plt
#       3
# ----> 4 sns.lineplot(x = "max_depth", y = "treino",data = resultados)
#       5 sns.lineplot(x = "max_depth", y = "teste",data = resultados)
#       6 plt.legend(["Treino", "Teste"])
#
# /usr/local/lib/python3.10/dist-packages/seaborn/relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, sort, err_style, err_kws, legend, ax, **kwargs)
#    1082         ax = plt.gca()
#    1083
# -> 1084     p.plot(ax, kwargs)
#    1085
#    1086     return ax
#
# /usr/local/lib/python3.10/dist-packages/seaborn/relational.py in plot(self, ax, kws)
#     773                     err = "estimator must be None when specifying units"
#     774                     raise ValueError(err)
# --> 775                 x, y, y_ci = self.aggregate(y, x, units)
#     776             else:
#     777                 y_ci = None
#
# /usr/local/lib/python3.10/dist-packages/seaborn/relational.py in aggregate(self, vals, grouper, units)
#     689
#     690         # Define a "null" CI for when we only have one value
# --> 691         null_ci = pd.Series(index=["low", "high"], dtype=np.float)
#     692
#     693         # Function to bootstrap in the context of a pandas group by
#
# /usr/local/lib/python3.10/dist-packages/numpy/__init__.py in __getattr__(attr)
#     317
#     318         if attr in __former_attrs__:
# --> 319             raise AttributeError(__former_attrs__[attr])
#     320
#     321         if attr == 'testing':
#
# AttributeError: module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
resultados.sort_values("treino", ascending=False).head()
# Out:
#    max_depth      teste  treino
# 2          3  78.754444   78.70
# 3          4  78.800000   78.63
# 4          5  78.965556   78.56
# 5          6  79.190000   78.49
# 6          7  79.443333   78.04

# %%
def roda_arvore_de_decisao(max_depth, min_samples_leaf):
  SEED = 301
  np.random.seed(SEED)

  modelo = DecisionTreeClassifier(max_depth=max_depth, min_samples_leaf=min_samples_leaf)
  results = cross_validate(modelo, x_azar, y_azar, cv = 10, return_train_score=True)
  train_score = results['train_score'].mean() * 100
  test_score = results['test_score'].mean() * 100
  media = results['test_score'].mean()
  desvio_padrao = results['test_score'].std()
  #print("Accuracy com cross validation, 10 = [%.2f, %.2f]" % ((media - 2 * desvio_padrao)*100, (media + 2 * desvio_padrao) * 100))
  print("Arvore max_depth = %d, min_samples_leaf = %d,teste = %.2f, treino = %.2f" % (max_depth, min_samples_leaf,test_score, train_score))
  tabela = [max_depth, min_samples_leaf,train_score, test_score]
  return tabela

def busca():
  resultados = []
  for max_depth in range(1,33):
    for min_samples_leaf in [32, 64, 128, 256]:
      tabela = roda_arvore_de_decisao(max_depth, min_samples_leaf)
      resultados.append(tabela)
  resultados = pd.DataFrame(resultados, columns = ["max_depth", "min_samples_leaf","teste", "treino"])
  return resultados
resultados = busca()
resultados.head()
# Out:
# Arvore max_depth = 1, min_samples_leaf = 32,teste = 75.78, treino = 75.79
# Arvore max_depth = 1, min_samples_leaf = 64,teste = 75.78, treino = 75.79
# Arvore max_depth = 1, min_samples_leaf = 128,teste = 75.78, treino = 75.79
# Arvore max_depth = 1, min_samples_leaf = 256,teste = 75.78, treino = 75.79
# Arvore max_depth = 2, min_samples_leaf = 32,teste = 75.78, treino = 75.79
# Arvore max_depth = 2, min_samples_leaf = 64,teste = 75.78, treino = 75.79
# Arvore max_depth = 2, min_samples_leaf = 128,teste = 75.78, treino = 75.79
# Arvore max_depth = 2, min_samples_leaf = 256,teste = 75.78, treino = 75.79
# Arvore max_depth = 3, min_samples_leaf = 32,teste = 78.70, treino = 78.75
# Arvore max_depth = 3, min_samples_leaf = 64,teste = 78.70, treino = 78.75
# Arvore max_depth = 3, min_samples_leaf = 128,teste = 78.70, treino = 78.75
# Arvore max_depth = 3, min_samples_leaf = 256,teste = 78.70, treino = 78.75
# Arvore max_depth = 4, min_samples_leaf = 32,teste = 78.65, treino = 78.76
# Arvore max_depth = 4, min_samples_leaf = 64,teste = 78.61, treino = 78.76
# Arvore max_depth = 4, min_samples_leaf = 128,teste = 78.70, treino = 78.75
# Arvore max_depth = 4, min_samples_leaf = 256,teste = 78.70, treino = 78.75
# Arvore max_depth = 5, min_samples_leaf = 32,teste = 78.46, treino = 78.80
# Arvore max_depth = 5, min_samples_leaf = 64,teste = 78.41, treino = 78.78
# Arvore max_depth = 5, min_samples_leaf = 128,teste = 78.32, treino = 78.79
# Arvore max_depth = 5, min_samples_leaf = 256,teste = 78.62, treino = 78.75
# Arvore max_depth = 6, min_samples_leaf = 32,teste = 77.87, treino = 78.91
# Arvore max_depth = 6, min_samples_leaf = 64,teste = 78.06, treino = 78.91
# Arvore max_depth = 6, min_samples_leaf = 128,teste = 77.84, treino = 78.88
# Arvore max_depth = 6, min_samples_leaf = 256,teste = 78.27, treino = 78.82
# Arvore max_depth = 7, min_samples_leaf = 32,teste = 77.81, treino = 79.11
# Arvore max_depth = 7, min_samples_leaf = 64,teste = 77.95, treino = 79.03
# Arvore max_depth = 7, min_samples_leaf = 128,teste = 77.84, treino = 78.94
# Arvore max_depth = 7, min_samples_leaf = 256,teste = 78.20, treino = 78.87
# Arvore max_depth = 8, min_samples_leaf = 32,teste = 77.73, treino = 79.31
# Arvore max_depth = 8, min_samples_leaf = 64,teste = 77.91, treino = 79.29
# Arvore max_depth = 8, min_samples_leaf = 128,teste = 77.54, treino = 79.05
# Arvore max_depth = 8, min_samples_leaf = 256,teste = 78.18, treino = 78.91
# Arvore max_depth = 9, min_samples_leaf = 32,teste = 77.31, treino = 79.57
# Arvore max_depth = 9, min_samples_leaf = 64,teste = 77.44, treino = 79.45
# Arvore max_depth = 9, min_samples_leaf = 128,teste = 77.45, treino = 79.13
# Arvore max_depth = 9, min_samples_leaf = 256,teste = 78.17, treino = 78.91
# Arvore max_depth = 10, min_samples_leaf = 32,teste = 77.55, treino = 79.84
# Arvore max_depth = 10, min_samples_leaf = 64,teste = 77.45, treino = 79.55
# Arvore max_depth = 10, min_samples_leaf = 128,teste = 77.44, treino = 79.17
# Arvore max_depth = 10, min_samples_leaf = 256,teste = 78.17, treino = 78.91
# Arvore max_depth = 11, min_samples_leaf = 32,teste = 77.47, treino = 80.01
# Arvore max_depth = 11, min_samples_leaf = 64,teste = 77.29, treino = 79.65
# Arvore max_depth = 11, min_samples_leaf = 128,teste = 77.44, treino = 79.19
# Arvore max_depth = 11, min_samples_leaf = 256,teste = 78.17, treino = 78.91
# Arvore max_depth = 12, min_samples_leaf = 32,teste = 77.10, treino = 80.20
# Arvore max_depth = 12, min_samples_leaf = 64,teste = 77.25, treino = 79.68
# Arvore max_depth = 12, min_samples_leaf = 128,teste = 77.44, treino = 79.19
# Arvore max_depth = 12, min_samples_leaf = 256,teste = 78.17, treino = 78.91
# Arvore max_depth = 13, min_samples_leaf = 32,teste = 77.06, treino = 80.37
# Arvore max_depth = 13, min_samples_leaf = 64,teste = 77.28, treino = 79.74
# Arvore max_depth = 13, min_samples_leaf = 128,teste = 77.44, treino = 79.19
# Arvore max_depth = 13, min_samples_leaf = 256,teste = 78.17, treino = 78.91
# Arvore max_depth = 14, min_samples_leaf = 32,teste = 77.08, treino = 80.49
# Arvore max_depth = 14, min_samples_leaf = 64,teste = 77.28, treino = 79.78
# Arvore max_depth = 14, min_samples_leaf = 128,teste = 77.44, treino = 79.19
# Arvore max_depth = 14, min_samples_leaf = 256,teste = 78.17, treino = 78.91
# Arvore max_depth = 15, min_samples_leaf = 32,teste = 76.78, treino = 80.58
# Arvore max_depth = 15, min_samples_leaf = 64,teste = 77.27, treino = 79.81
# Arvore max_depth = 15, min_samples_leaf = 128,teste = 77.44, treino = 79.19
# Arvore max_depth = 15, min_samples_leaf = 256,teste = 78.17, treino = 78.91
# Arvore max_depth = 16, min_samples_leaf = 32,teste = 76.85, treino = 80.69
# Arvore max_depth = 16, min_samples_leaf = 64,teste = 77.21, treino = 79.84
# Arvore max_depth = 16, min_samples_leaf = 128,teste = 77.44, treino = 79.19
# Arvore max_depth = 16, min_samples_leaf = 256,teste = 78.17, treino = 78.91
# Arvore max_depth = 17, min_samples_leaf = 32,teste = 76.83, treino = 80.72
# Arvore max_depth = 17, min_samples_leaf = 64,teste = 77.18, treino = 79.85
# Arvore max_depth = 17, min_samples_leaf = 128,teste = 77.44, treino = 79.19
# Arvore max_depth = 17, min_samples_leaf = 256,teste = 78.17, treino = 78.91
# Arvore max_depth = 18, min_samples_leaf = 32,teste = 76.84, treino = 80.74
# Arvore max_depth = 18, min_samples_leaf = 64,teste = 77.18, treino = 79.85
# Arvore max_depth = 18, min_samples_leaf = 128,teste = 77.44, treino = 79.19
# Arvore max_depth = 18, min_samples_leaf = 256,teste = 78.17, treino = 78.91
# Arvore max_depth = 19, min_samples_leaf = 32,teste = 76.81, treino = 80.80
# Arvore max_depth = 19, min_samples_leaf = 64,teste = 77.18, treino = 79.85
# Arvore max_depth = 19, min_samples_leaf = 128,teste = 77.44, treino = 79.19
# Arvore max_depth = 19, min_samples_leaf = 256,teste = 78.17, treino = 78.91
# Arvore max_depth = 20, min_samples_leaf = 32,teste = 76.83, treino = 80.81
# Arvore max_depth = 20, min_samples_leaf = 64,teste = 77.18, treino = 79.85
# Arvore max_depth = 20, min_samples_leaf = 128,teste = 77.44, treino = 79.19
# Arvore max_depth = 20, min_samples_leaf = 256,teste = 78.17, treino = 78.91
# Arvore max_depth = 21, min_samples_leaf = 32,teste = 76.81, treino = 80.82
# Arvore max_depth = 21, min_samples_leaf = 64,teste = 77.18, treino = 79.85
# Arvore max_depth = 21, min_samples_leaf = 128,teste = 77.44, treino = 79.19
# Arvore max_depth = 21, min_samples_leaf = 256,teste = 78.17, treino = 78.91
# Arvore max_depth = 22, min_samples_leaf = 32,teste = 76.82, treino = 80.83
# Arvore max_depth = 22, min_samples_leaf = 64,teste = 77.18, treino = 79.85
# Arvore max_depth = 22, min_samples_leaf = 128,teste = 77.44, treino = 79.19
# Arvore max_depth = 22, min_samples_leaf = 256,teste = 78.17, treino = 78.91
# Arvore max_depth = 23, min_samples_leaf = 32,teste = 76.81, treino = 80.84
# Arvore max_depth = 23, min_samples_leaf = 64,teste = 77.18, treino = 79.85
# Arvore max_depth = 23, min_samples_leaf = 128,teste = 77.44, treino = 79.19
# Arvore max_depth = 23, min_samples_leaf = 256,teste = 78.17, treino = 78.91
# Arvore max_depth = 24, min_samples_leaf = 32,teste = 76.81, treino = 80.84
# Arvore max_depth = 24, min_samples_leaf = 64,teste = 77.18, treino = 79.85
# Arvore max_depth = 24, min_samples_leaf = 128,teste = 77.44, treino = 79.19
# Arvore max_depth = 24, min_samples_leaf = 256,teste = 78.17, treino = 78.91
# Arvore max_depth = 25, min_samples_leaf = 32,teste = 76.81, treino = 80.84
# Arvore max_depth = 25, min_samples_leaf = 64,teste = 77.18, treino = 79.85
# Arvore max_depth = 25, min_samples_leaf = 128,teste = 77.44, treino = 79.19
# Arvore max_depth = 25, min_samples_leaf = 256,teste = 78.17, treino = 78.91
# Arvore max_depth = 26, min_samples_leaf = 32,teste = 76.81, treino = 80.84
# Arvore max_depth = 26, min_samples_leaf = 64,teste = 77.18, treino = 79.85
# Arvore max_depth = 26, min_samples_leaf = 128,teste = 77.44, treino = 79.19
# Arvore max_depth = 26, min_samples_leaf = 256,teste = 78.17, treino = 78.91
# Arvore max_depth = 27, min_samples_leaf = 32,teste = 76.81, treino = 80.84
# Arvore max_depth = 27, min_samples_leaf = 64,teste = 77.18, treino = 79.85
# Arvore max_depth = 27, min_samples_leaf = 128,teste = 77.44, treino = 79.19
# Arvore max_depth = 27, min_samples_leaf = 256,teste = 78.17, treino = 78.91
# Arvore max_depth = 28, min_samples_leaf = 32,teste = 76.81, treino = 80.84
# Arvore max_depth = 28, min_samples_leaf = 64,teste = 77.18, treino = 79.85
# Arvore max_depth = 28, min_samples_leaf = 128,teste = 77.44, treino = 79.19
# Arvore max_depth = 28, min_samples_leaf = 256,teste = 78.17, treino = 78.91
# Arvore max_depth = 29, min_samples_leaf = 32,teste = 76.81, treino = 80.84
# Arvore max_depth = 29, min_samples_leaf = 64,teste = 77.18, treino = 79.85
# Arvore max_depth = 29, min_samples_leaf = 128,teste = 77.44, treino = 79.19
# Arvore max_depth = 29, min_samples_leaf = 256,teste = 78.17, treino = 78.91
# Arvore max_depth = 30, min_samples_leaf = 32,teste = 76.81, treino = 80.84
# Arvore max_depth = 30, min_samples_leaf = 64,teste = 77.18, treino = 79.85
# Arvore max_depth = 30, min_samples_leaf = 128,teste = 77.44, treino = 79.19
# Arvore max_depth = 30, min_samples_leaf = 256,teste = 78.17, treino = 78.91
# Arvore max_depth = 31, min_samples_leaf = 32,teste = 76.81, treino = 80.84
# Arvore max_depth = 31, min_samples_leaf = 64,teste = 77.18, treino = 79.85
# Arvore max_depth = 31, min_samples_leaf = 128,teste = 77.44, treino = 79.19
# Arvore max_depth = 31, min_samples_leaf = 256,teste = 78.17, treino = 78.91
# Arvore max_depth = 32, min_samples_leaf = 32,teste = 76.81, treino = 80.84
# Arvore max_depth = 32, min_samples_leaf = 64,teste = 77.18, treino = 79.85
# Arvore max_depth = 32, min_samples_leaf = 128,teste = 77.44, treino = 79.19
# Arvore max_depth = 32, min_samples_leaf = 256,teste = 78.17, treino = 78.91
#    max_depth  min_samples_leaf      teste  treino
# 0          1                32  75.791111   75.78
# 1          1                64  75.791111   75.78
# 2          1               128  75.791111   75.78
# 3          1               256  75.791111   75.78
# 4          2                32  75.791111   75.78

# %%
resultados.sort_values("teste", ascending=False).head()
# Out:
#      max_depth  min_samples_leaf      teste  treino
# 96          25                32  80.843333   76.81
# 120         31                32  80.843333   76.81
# 88          23                32  80.843333   76.81
# 100         26                32  80.843333   76.81
# 112         29                32  80.843333   76.81

# %%
corr = resultados.corr()

# %%
sns.heatmap(corr)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-911aa23b3c54> in <cell line: 1>()
# ----> 1 sns.heatmap(corr)
#
# /usr/local/lib/python3.10/dist-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     513     """
#     514     # Initialize the plotter object
# --> 515     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     516                           annot_kws, cbar, cbar_kws, xticklabels,
#     517                           yticklabels, mask)
#
# /usr/local/lib/python3.10/dist-packages/seaborn/matrix.py in __init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
#     111
#     112         # Validate the mask and convet to DataFrame
# --> 113         mask = _matrix_mask(data, mask)
#     114
#     115         plot_data = np.ma.masked_where(np.asarray(mask), plot_data)
#
# /usr/local/lib/python3.10/dist-packages/seaborn/matrix.py in _matrix_mask(data, mask)
#      68     """
#      69     if mask is None:
# ---> 70         mask = np.zeros(data.shape, np.bool)
#      71
#      72     if isinstance(mask, np.ndarray):
#
# /usr/local/lib/python3.10/dist-packages/numpy/__init__.py in __getattr__(attr)
#     317
#     318         if attr in __former_attrs__:
# --> 319             raise AttributeError(__former_attrs__[attr])
#     320
#     321         if attr == 'testing':
#
# AttributeError: module 'numpy' has no attribute 'bool'.
# `np.bool` was a deprecated alias for the builtin `bool`. To avoid this error in existing code, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
pd.plotting.scatter_matrix(resultados, figsize=(20,10), alpha = 0.3)
# Out:
# array([[<Axes: xlabel='max_depth', ylabel='max_depth'>,
#         <Axes: xlabel='min_samples_leaf', ylabel='max_depth'>,
#         <Axes: xlabel='teste', ylabel='max_depth'>,
#         <Axes: xlabel='treino', ylabel='max_depth'>],
#        [<Axes: xlabel='max_depth', ylabel='min_samples_leaf'>,
#         <Axes: xlabel='min_samples_leaf', ylabel='min_samples_leaf'>,
#         <Axes: xlabel='teste', ylabel='min_samples_leaf'>,
#         <Axes: xlabel='treino', ylabel='min_samples_leaf'>],
#        [<Axes: xlabel='max_depth', ylabel='teste'>,
#         <Axes: xlabel='min_samples_leaf', ylabel='teste'>,
#         <Axes: xlabel='teste', ylabel='teste'>,
#         <Axes: xlabel='treino', ylabel='teste'>],
#        [<Axes: xlabel='max_depth', ylabel='treino'>,
#         <Axes: xlabel='min_samples_leaf', ylabel='treino'>,
#         <Axes: xlabel='teste', ylabel='treino'>,
#         <Axes: xlabel='treino', ylabel='treino'>]], dtype=object)

# %%
sns.pairplot(resultados)

# %%
from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="white")

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
def busca():
  resultados = []
  for max_depth in range(1,33):
    for min_samples_leaf in [128, 192, 256, 512]:
      tabela = roda_arvore_de_decisao(max_depth, min_samples_leaf)
      resultados.append(tabela)
  resultados = pd.DataFrame(resultados, columns = ["max_depth", "min_samples_leaf","teste", "treino"])
  return resultados
resultados = busca()
resultados.head()
# Out:
# Arvore max_depth = 1, min_samples_leaf = 128,teste = 75.78, treino = 75.79
# Arvore max_depth = 1, min_samples_leaf = 192,teste = 75.78, treino = 75.79
# Arvore max_depth = 1, min_samples_leaf = 256,teste = 75.78, treino = 75.79
# Arvore max_depth = 1, min_samples_leaf = 512,teste = 75.78, treino = 75.79
# Arvore max_depth = 2, min_samples_leaf = 128,teste = 75.78, treino = 75.79
# Arvore max_depth = 2, min_samples_leaf = 192,teste = 75.78, treino = 75.79
# Arvore max_depth = 2, min_samples_leaf = 256,teste = 75.78, treino = 75.79
# Arvore max_depth = 2, min_samples_leaf = 512,teste = 75.78, treino = 75.79
# Arvore max_depth = 3, min_samples_leaf = 128,teste = 78.70, treino = 78.75
# Arvore max_depth = 3, min_samples_leaf = 192,teste = 78.70, treino = 78.75
# Arvore max_depth = 3, min_samples_leaf = 256,teste = 78.70, treino = 78.75
# Arvore max_depth = 3, min_samples_leaf = 512,teste = 77.47, treino = 77.53
# Arvore max_depth = 4, min_samples_leaf = 128,teste = 78.70, treino = 78.75
# Arvore max_depth = 4, min_samples_leaf = 192,teste = 78.70, treino = 78.75
# Arvore max_depth = 4, min_samples_leaf = 256,teste = 78.70, treino = 78.75
# Arvore max_depth = 4, min_samples_leaf = 512,teste = 77.47, treino = 77.53
# Arvore max_depth = 5, min_samples_leaf = 128,teste = 78.32, treino = 78.79
# Arvore max_depth = 5, min_samples_leaf = 192,teste = 78.44, treino = 78.77
# Arvore max_depth = 5, min_samples_leaf = 256,teste = 78.62, treino = 78.75
# Arvore max_depth = 5, min_samples_leaf = 512,teste = 77.47, treino = 77.53
# Arvore max_depth = 6, min_samples_leaf = 128,teste = 77.84, treino = 78.88
# Arvore max_depth = 6, min_samples_leaf = 192,teste = 78.09, treino = 78.85
# Arvore max_depth = 6, min_samples_leaf = 256,teste = 78.27, treino = 78.82
# Arvore max_depth = 6, min_samples_leaf = 512,teste = 77.47, treino = 77.53
# Arvore max_depth = 7, min_samples_leaf = 128,teste = 77.84, treino = 78.94
# Arvore max_depth = 7, min_samples_leaf = 192,teste = 78.04, treino = 78.86
# Arvore max_depth = 7, min_samples_leaf = 256,teste = 78.20, treino = 78.87
# Arvore max_depth = 7, min_samples_leaf = 512,teste = 77.47, treino = 77.53
# Arvore max_depth = 8, min_samples_leaf = 128,teste = 77.54, treino = 79.05
# Arvore max_depth = 8, min_samples_leaf = 192,teste = 77.89, treino = 78.91
# Arvore max_depth = 8, min_samples_leaf = 256,teste = 78.18, treino = 78.91
# Arvore max_depth = 8, min_samples_leaf = 512,teste = 77.47, treino = 77.53
# Arvore max_depth = 9, min_samples_leaf = 128,teste = 77.45, treino = 79.13
# Arvore max_depth = 9, min_samples_leaf = 192,teste = 77.95, treino = 78.94
# Arvore max_depth = 9, min_samples_leaf = 256,teste = 78.17, treino = 78.91
# Arvore max_depth = 9, min_samples_leaf = 512,teste = 77.47, treino = 77.53
# Arvore max_depth = 10, min_samples_leaf = 128,teste = 77.44, treino = 79.17
# Arvore max_depth = 10, min_samples_leaf = 192,teste = 77.97, treino = 78.98
# Arvore max_depth = 10, min_samples_leaf = 256,teste = 78.17, treino = 78.91
# Arvore max_depth = 10, min_samples_leaf = 512,teste = 77.47, treino = 77.53
# Arvore max_depth = 11, min_samples_leaf = 128,teste = 77.44, treino = 79.19
# Arvore max_depth = 11, min_samples_leaf = 192,teste = 77.97, treino = 78.98
# Arvore max_depth = 11, min_samples_leaf = 256,teste = 78.17, treino = 78.91
# Arvore max_depth = 11, min_samples_leaf = 512,teste = 77.47, treino = 77.53
# Arvore max_depth = 12, min_samples_leaf = 128,teste = 77.44, treino = 79.19
# Arvore max_depth = 12, min_samples_leaf = 192,teste = 77.97, treino = 78.98
# Arvore max_depth = 12, min_samples_leaf = 256,teste = 78.17, treino = 78.91
# Arvore max_depth = 12, min_samples_leaf = 512,teste = 77.47, treino = 77.53
# Arvore max_depth = 13, min_samples_leaf = 128,teste = 77.44, treino = 79.19
# Arvore max_depth = 13, min_samples_leaf = 192,teste = 77.97, treino = 78.98
# Arvore max_depth = 13, min_samples_leaf = 256,teste = 78.17, treino = 78.91
# Arvore max_depth = 13, min_samples_leaf = 512,teste = 77.47, treino = 77.53
# Arvore max_depth = 14, min_samples_leaf = 128,teste = 77.44, treino = 79.19
# Arvore max_depth = 14, min_samples_leaf = 192,teste = 77.97, treino = 78.98
# Arvore max_depth = 14, min_samples_leaf = 256,teste = 78.17, treino = 78.91
# Arvore max_depth = 14, min_samples_leaf = 512,teste = 77.47, treino = 77.53
# Arvore max_depth = 15, min_samples_leaf = 128,teste = 77.44, treino = 79.19
# Arvore max_depth = 15, min_samples_leaf = 192,teste = 77.97, treino = 78.98
# Arvore max_depth = 15, min_samples_leaf = 256,teste = 78.17, treino = 78.91
# Arvore max_depth = 15, min_samples_leaf = 512,teste = 77.47, treino = 77.53
# Arvore max_depth = 16, min_samples_leaf = 128,teste = 77.44, treino = 79.19
# Arvore max_depth = 16, min_samples_leaf = 192,teste = 77.97, treino = 78.98
# Arvore max_depth = 16, min_samples_leaf = 256,teste = 78.17, treino = 78.91
# Arvore max_depth = 16, min_samples_leaf = 512,teste = 77.47, treino = 77.53
# Arvore max_depth = 17, min_samples_leaf = 128,teste = 77.44, treino = 79.19
# Arvore max_depth = 17, min_samples_leaf = 192,teste = 77.97, treino = 78.98
# Arvore max_depth = 17, min_samples_leaf = 256,teste = 78.17, treino = 78.91
# Arvore max_depth = 17, min_samples_leaf = 512,teste = 77.47, treino = 77.53
# Arvore max_depth = 18, min_samples_leaf = 128,teste = 77.44, treino = 79.19
# Arvore max_depth = 18, min_samples_leaf = 192,teste = 77.97, treino = 78.98
# Arvore max_depth = 18, min_samples_leaf = 256,teste = 78.17, treino = 78.91
# Arvore max_depth = 18, min_samples_leaf = 512,teste = 77.47, treino = 77.53
# Arvore max_depth = 19, min_samples_leaf = 128,teste = 77.44, treino = 79.19
# Arvore max_depth = 19, min_samples_leaf = 192,teste = 77.97, treino = 78.98
# Arvore max_depth = 19, min_samples_leaf = 256,teste = 78.17, treino = 78.91
# Arvore max_depth = 19, min_samples_leaf = 512,teste = 77.47, treino = 77.53
# Arvore max_depth = 20, min_samples_leaf = 128,teste = 77.44, treino = 79.19
# Arvore max_depth = 20, min_samples_leaf = 192,teste = 77.97, treino = 78.98
# Arvore max_depth = 20, min_samples_leaf = 256,teste = 78.17, treino = 78.91
# Arvore max_depth = 20, min_samples_leaf = 512,teste = 77.47, treino = 77.53
# Arvore max_depth = 21, min_samples_leaf = 128,teste = 77.44, treino = 79.19
# Arvore max_depth = 21, min_samples_leaf = 192,teste = 77.97, treino = 78.98
# Arvore max_depth = 21, min_samples_leaf = 256,teste = 78.17, treino = 78.91
# Arvore max_depth = 21, min_samples_leaf = 512,teste = 77.47, treino = 77.53
# Arvore max_depth = 22, min_samples_leaf = 128,teste = 77.44, treino = 79.19
# Arvore max_depth = 22, min_samples_leaf = 192,teste = 77.97, treino = 78.98
# Arvore max_depth = 22, min_samples_leaf = 256,teste = 78.17, treino = 78.91
# Arvore max_depth = 22, min_samples_leaf = 512,teste = 77.47, treino = 77.53
# Arvore max_depth = 23, min_samples_leaf = 128,teste = 77.44, treino = 79.19
# Arvore max_depth = 23, min_samples_leaf = 192,teste = 77.97, treino = 78.98
# Arvore max_depth = 23, min_samples_leaf = 256,teste = 78.17, treino = 78.91
# Arvore max_depth = 23, min_samples_leaf = 512,teste = 77.47, treino = 77.53
# Arvore max_depth = 24, min_samples_leaf = 128,teste = 77.44, treino = 79.19
# Arvore max_depth = 24, min_samples_leaf = 192,teste = 77.97, treino = 78.98
# Arvore max_depth = 24, min_samples_leaf = 256,teste = 78.17, treino = 78.91
# Arvore max_depth = 24, min_samples_leaf = 512,teste = 77.47, treino = 77.53
# Arvore max_depth = 25, min_samples_leaf = 128,teste = 77.44, treino = 79.19
# Arvore max_depth = 25, min_samples_leaf = 192,teste = 77.97, treino = 78.98
# Arvore max_depth = 25, min_samples_leaf = 256,teste = 78.17, treino = 78.91
# Arvore max_depth = 25, min_samples_leaf = 512,teste = 77.47, treino = 77.53
# Arvore max_depth = 26, min_samples_leaf = 128,teste = 77.44, treino = 79.19
# Arvore max_depth = 26, min_samples_leaf = 192,teste = 77.97, treino = 78.98
# Arvore max_depth = 26, min_samples_leaf = 256,teste = 78.17, treino = 78.91
# Arvore max_depth = 26, min_samples_leaf = 512,teste = 77.47, treino = 77.53
# Arvore max_depth = 27, min_samples_leaf = 128,teste = 77.44, treino = 79.19
# Arvore max_depth = 27, min_samples_leaf = 192,teste = 77.97, treino = 78.98
# Arvore max_depth = 27, min_samples_leaf = 256,teste = 78.17, treino = 78.91
# Arvore max_depth = 27, min_samples_leaf = 512,teste = 77.47, treino = 77.53
# Arvore max_depth = 28, min_samples_leaf = 128,teste = 77.44, treino = 79.19
# Arvore max_depth = 28, min_samples_leaf = 192,teste = 77.97, treino = 78.98
# Arvore max_depth = 28, min_samples_leaf = 256,teste = 78.17, treino = 78.91
# Arvore max_depth = 28, min_samples_leaf = 512,teste = 77.47, treino = 77.53
# Arvore max_depth = 29, min_samples_leaf = 128,teste = 77.44, treino = 79.19
# Arvore max_depth = 29, min_samples_leaf = 192,teste = 77.97, treino = 78.98
# Arvore max_depth = 29, min_samples_leaf = 256,teste = 78.17, treino = 78.91
# Arvore max_depth = 29, min_samples_leaf = 512,teste = 77.47, treino = 77.53
# Arvore max_depth = 30, min_samples_leaf = 128,teste = 77.44, treino = 79.19
# Arvore max_depth = 30, min_samples_leaf = 192,teste = 77.97, treino = 78.98
# Arvore max_depth = 30, min_samples_leaf = 256,teste = 78.17, treino = 78.91
# Arvore max_depth = 30, min_samples_leaf = 512,teste = 77.47, treino = 77.53
# Arvore max_depth = 31, min_samples_leaf = 128,teste = 77.44, treino = 79.19
# Arvore max_depth = 31, min_samples_leaf = 192,teste = 77.97, treino = 78.98
# Arvore max_depth = 31, min_samples_leaf = 256,teste = 78.17, treino = 78.91
# Arvore max_depth = 31, min_samples_leaf = 512,teste = 77.47, treino = 77.53
# Arvore max_depth = 32, min_samples_leaf = 128,teste = 77.44, treino = 79.19
# Arvore max_depth = 32, min_samples_leaf = 192,teste = 77.97, treino = 78.98
# Arvore max_depth = 32, min_samples_leaf = 256,teste = 78.17, treino = 78.91
# Arvore max_depth = 32, min_samples_leaf = 512,teste = 77.47, treino = 77.53
#    max_depth  min_samples_leaf      teste  treino
# 0          1               128  75.791111   75.78
# 1          1               192  75.791111   75.78
# 2          1               256  75.791111   75.78
# 3          1               512  75.791111   75.78
# 4          2               128  75.791111   75.78

# %%
corr = resultados.corr()
from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="white")

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-ce4070818a3f> in <cell line: 18>()
#      16
#      17 # Generate a custom diverging colormap
# ---> 18 cmap = sns.diverging_palette(220, 10, as_cmap=True)
#      19
#      20 # Draw the heatmap with the mask and correct aspect ratio
#
# /usr/local/lib/python3.10/dist-packages/seaborn/palettes.py in diverging_palette(h_neg, h_pos, s, l, sep, n, center, as_cmap)
#     742     """
#     743     palfunc = dark_palette if center == "dark" else light_palette
# --> 744     neg = palfunc((h_neg, s, l), 128 - (sep / 2), reverse=True, input="husl")
#     745     pos = palfunc((h_pos, s, l), 128 - (sep / 2), input="husl")
#     746     midpoint = dict(light=[(.95, .95, .95, 1.)],
#
# /usr/local/lib/python3.10/dist-packages/seaborn/palettes.py in light_palette(color, n_colors, reverse, as_cmap, input)
#     639     light = set_hls_values(color, l=.95)  # noqa
#     640     colors = [color, light] if reverse else [light, color]
# --> 641     return blend_palette(colors, n_colors, as_cmap)
#     642
#     643
#
# /usr/local/lib/python3.10/dist-packages/seaborn/palettes.py in blend_palette(colors, n_colors, as_cmap, input)
#     775     pal = mpl.colors.LinearSegmentedColormap.from_list(name, colors)
#     776     if not as_cmap:
# --> 777         pal = _ColorPalette(pal(np.linspace(0, 1, n_colors)))
#     778     return pal
#     779
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/function_base.py in linspace(start, stop, num, endpoint, retstep, dtype, axis)
#     120
#     121     """
# --> 122     num = operator.index(num)
#     123     if num < 0:
#     124         raise ValueError("Number of samples, %s, must be non-negative." % num)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
resultados.sort_values("teste", ascending=False).head()
# Out:
#      max_depth  min_samples_leaf      teste  treino
# 64          17               128  79.188889   77.44
# 116         30               128  79.188889   77.44
# 112         29               128  79.188889   77.44
# 44          12               128  79.188889   77.44
# 52          14               128  79.188889   77.44

# %%
def roda_arvore_de_decisao(max_depth, min_samples_leaf, min_samples_split):
  SEED = 301
  np.random.seed(SEED)

  modelo = DecisionTreeClassifier(max_depth=max_depth, min_samples_leaf=min_samples_leaf, min_samples_split=min_samples_split)
  results = cross_validate(modelo, x_azar, y_azar, cv = 10, return_train_score=True)
  fit_time = results['fit_time'].mean()
  score_time = results['score_time'].mean()
  train_score = results['train_score'].mean() * 100
  test_score = results['test_score'].mean() * 100
  media = results['test_score'].mean()
  desvio_padrao = results['test_score'].std()
  #print("Accuracy com cross validation, 10 = [%.2f, %.2f]" % ((media - 2 * desvio_padrao)*100, (media + 2 * desvio_padrao) * 100))
  #print("Arvore max_depth = %d, min_samples_leaf = %d, min_samples_split = %d,teste = %.2f, treino = %.2f" % (max_depth, min_samples_leaf, min_samples_split,test_score, train_score))
  tabela = [max_depth, min_samples_leaf, min_samples_split,train_score, test_score, fit_time, score_time]
  return tabela

def busca():
  resultados = []
  for max_depth in range(1,33):
    for min_samples_leaf in [32, 64, 128, 256]:
      for min_samples_split in [32, 64, 128, 256]:
        tabela = roda_arvore_de_decisao(max_depth, min_samples_leaf, min_samples_split)
        resultados.append(tabela)
  resultados = pd.DataFrame(resultados, columns = ["max_depth", "min_samples_leaf", "min_samples_split","teste", "treino", "fit_time", "score_time"])
  return resultados
resultados = busca()
resultados.head()
# Out:
#    max_depth  min_samples_leaf  min_samples_split      teste  treino  \
# 0          1                32                 32  75.791111   75.78
# 1          1                32                 64  75.791111   75.78
# 2          1                32                128  75.791111   75.78
# 3          1                32                256  75.791111   75.78
# 4          1                64                 32  75.791111   75.78
#
#    fit_time  score_time
# 0  0.006318    0.002059
# 1  0.006842    0.002357
# 2  0.006420    0.002307
# 3  0.006250    0.002195
# 4  0.006166    0.002065

# %%
corr = resultados.corr()
sns.set(style="white")

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-e549e94a750e> in <cell line: 12>()
#      10
#      11 # Generate a custom diverging colormap
# ---> 12 cmap = sns.diverging_palette(220, 10, as_cmap=True)
#      13
#      14 # Draw the heatmap with the mask and correct aspect ratio
#
# /usr/local/lib/python3.10/dist-packages/seaborn/palettes.py in diverging_palette(h_neg, h_pos, s, l, sep, n, center, as_cmap)
#     742     """
#     743     palfunc = dark_palette if center == "dark" else light_palette
# --> 744     neg = palfunc((h_neg, s, l), 128 - (sep / 2), reverse=True, input="husl")
#     745     pos = palfunc((h_pos, s, l), 128 - (sep / 2), input="husl")
#     746     midpoint = dict(light=[(.95, .95, .95, 1.)],
#
# /usr/local/lib/python3.10/dist-packages/seaborn/palettes.py in light_palette(color, n_colors, reverse, as_cmap, input)
#     639     light = set_hls_values(color, l=.95)  # noqa
#     640     colors = [color, light] if reverse else [light, color]
# --> 641     return blend_palette(colors, n_colors, as_cmap)
#     642
#     643
#
# /usr/local/lib/python3.10/dist-packages/seaborn/palettes.py in blend_palette(colors, n_colors, as_cmap, input)
#     775     pal = mpl.colors.LinearSegmentedColormap.from_list(name, colors)
#     776     if not as_cmap:
# --> 777         pal = _ColorPalette(pal(np.linspace(0, 1, n_colors)))
#     778     return pal
#     779
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/function_base.py in linspace(start, stop, num, endpoint, retstep, dtype, axis)
#     120
#     121     """
# --> 122     num = operator.index(num)
#     123     if num < 0:
#     124         raise ValueError("Number of samples, %s, must be non-negative." % num)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
resultados.sort_values("teste", ascending=False).head()
# Out:
#      max_depth  min_samples_leaf  min_samples_split      teste  treino  \
# 352         23                32                 32  80.843333   76.81
# 496         32                32                 32  80.843333   76.81
# 465         30                32                 64  80.843333   76.81
# 464         30                32                 32  80.843333   76.81
# 449         29                32                 64  80.843333   76.81
#
#      fit_time  score_time
# 352  0.069237    0.007947
# 496  0.036113    0.003882
# 465  0.039871    0.003895
# 464  0.043167    0.004760
# 449  0.027098    0.002620

# %%
from sklearn.model_selection import GridSearchCV
SEED=301
np.random.seed(SEED)

espaco_de_parametros = {
    "max_depth" : [3, 5],
    "min_samples_split": [32, 64, 128],
    "min_samples_leaf": [32, 64, 128],
    "criterion": ["gini", "entropy"]

}

busca = GridSearchCV(DecisionTreeClassifier(),
                    espaco_de_parametros,
                    cv = GroupKFold(n_splits = 10))

busca.fit(x_azar, y_azar,groups = dados.modelo)
resultados = pd.DataFrame(busca.cv_results_)
resultados.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.015720      0.004039         0.003545        0.000981
# 1       0.015718      0.003851         0.003326        0.000609
# 2       0.014533      0.001850         0.003741        0.000916
# 3       0.014599      0.002181         0.003645        0.001090
# 4       0.018160      0.001454         0.004367        0.001140
#
#   param_criterion param_max_depth param_min_samples_leaf  \
# 0            gini               3                     32
# 1            gini               3                     32
# 2            gini               3                     32
# 3            gini               3                     64
# 4            gini               3                     64
#
#   param_min_samples_split                                             params  \
# 0                      32  {'criterion': 'gini', 'max_depth': 3, 'min_sam...
# 1                      64  {'criterion': 'gini', 'max_depth': 3, 'min_sam...
# 2                     128  {'criterion': 'gini', 'max_depth': 3, 'min_sam...
# 3                      32  {'criterion': 'gini', 'max_depth': 3, 'min_sam...
# 4                      64  {'criterion': 'gini', 'max_depth': 3, 'min_sam...
#
#    split0_test_score  ...  split3_test_score  split4_test_score  \
# 0           0.804757  ...            0.78408           0.783181
# 1           0.804757  ...            0.78408           0.783181
# 2           0.804757  ...            0.78408           0.783181
# 3           0.804757  ...            0.78408           0.783181
# 4           0.804757  ...            0.78408           0.783181
#
#    split5_test_score  split6_test_score  split7_test_score  split8_test_score  \
# 0           0.797809           0.762866           0.781818            0.77551
# 1           0.797809           0.762866           0.781818            0.77551
# 2           0.797809           0.762866           0.781818            0.77551
# 3           0.797809           0.762866           0.781818            0.77551
# 4           0.797809           0.762866           0.781818            0.77551
#
#    split9_test_score  mean_test_score  std_test_score  rank_test_score
# 0           0.790262         0.786726        0.011361                1
# 1           0.790262         0.786726        0.011361                1
# 2           0.790262         0.786726        0.011361                1
# 3           0.790262         0.786726        0.011361                1
# 4           0.790262         0.786726        0.011361                1
#
# [5 rows x 22 columns]

# %%
print(busca.best_params_)
print(busca.best_score_ * 100)
# Out:
# {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 32, 'min_samples_split': 32}
# 78.67263337284332

# %%
melhor = busca.best_estimator_
melhor
# Out:
# DecisionTreeClassifier(max_depth=3, min_samples_leaf=32, min_samples_split=32)

# %%
from sklearn.metrics import accuracy_score

#Evitar essa abordagem pois é otimista

predicoes = melhor.predict(x_azar)
accuracy = accuracy_score(predicoes, y_azar) * 100
print(f"Accuracy para os dados foi {accuracy}%")
# Out:
# Accuracy para os dados foi 78.75%

# %%
#Nested cross validate
from sklearn.model_selection import cross_val_score

scores = cross_val_score(busca, x_azar, y_azar, cv = GroupKFold(n_splits=10), groups = dados.modelo)

#Infelizmente o Pandas ainda está com o bug e não suporta nested validation com group k fold. Logo não conseguimos prever o resultado para novos grupos
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-e3e710ebe2ce> in <cell line: 4>()
#       2 from sklearn.model_selection import cross_val_score
#       3
# ----> 4 scores = cross_val_score(busca, x_azar, y_azar, cv = GroupKFold(n_splits=10), groups = dados.modelo)
#       5
#       6 #Infelizmente o Pandas ainda está com o bug e não suporta nested validation com group k fold. Logo não conseguimos prever o resultado para novos grupos
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     513     scorer = check_scoring(estimator, scoring=scoring)
#     514
# --> 515     cv_results = cross_validate(
#     516         estimator=estimator,
#     517         X=X,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     283     )
#     284
# --> 285     _warn_or_raise_about_fit_failures(results, error_score)
#     286
#     287     # For callabe scoring, the return type is only know after calling. If the
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py in _warn_or_raise_about_fit_failures(results, error_score)
#     365                 f"Below are more details about the failures:\n{fit_errors_summary}"
#     366             )
# --> 367             raise ValueError(all_fits_failed_message)
#     368
#     369         else:
#
# ValueError:
# All the 10 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py", line 874, in fit
#     self._run_search(evaluate_candidates)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py", line 1388, in _run_search
#     evaluate_candidates(ParameterGrid(self.param_grid))
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py", line 833, in evaluate_candidates
#     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py", line 352, in split
#     for train, test in super().split(X, y, groups):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py", line 85, in split
#     for test_index in self._iter_test_masks(X, y, groups):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py", line 97, in _iter_test_masks
#     for test_index in self._iter_test_indices(X, y, groups):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py", line 530, in _iter_test_indices
#     raise ValueError("The 'groups' parameter should not be None.")
# ValueError: The 'groups' parameter should not be None.

# %%
from sklearn.model_selection import GridSearchCV, KFold

SEED=301
np.random.seed(SEED)

espaco_de_parametros = {
    "max_depth" : [3, 5],
    "min_samples_split": [32, 64, 128],
    "min_samples_leaf": [32, 64, 128],
    "criterion": ["gini", "entropy"]

}

busca = GridSearchCV(DecisionTreeClassifier(),
                    espaco_de_parametros,
                    cv = KFold(n_splits = 5, shuffle=True))

busca.fit(x_azar, y_azar)
resultados = pd.DataFrame(busca.cv_results_)
resultados.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.013256      0.001688         0.002990        0.000279
# 1       0.012152      0.001190         0.003695        0.000936
# 2       0.012076      0.000469         0.003732        0.000643
# 3       0.011482      0.000628         0.003109        0.000511
# 4       0.012228      0.001233         0.003418        0.000928
#
#   param_criterion param_max_depth param_min_samples_leaf  \
# 0            gini               3                     32
# 1            gini               3                     32
# 2            gini               3                     32
# 3            gini               3                     64
# 4            gini               3                     64
#
#   param_min_samples_split                                             params  \
# 0                      32  {'criterion': 'gini', 'max_depth': 3, 'min_sam...
# 1                      64  {'criterion': 'gini', 'max_depth': 3, 'min_sam...
# 2                     128  {'criterion': 'gini', 'max_depth': 3, 'min_sam...
# 3                      32  {'criterion': 'gini', 'max_depth': 3, 'min_sam...
# 4                      64  {'criterion': 'gini', 'max_depth': 3, 'min_sam...
#
#    split0_test_score  split1_test_score  split2_test_score  split3_test_score  \
# 0              0.784              0.776             0.8025              0.793
# 1              0.784              0.776             0.8025              0.793
# 2              0.784              0.776             0.8025              0.793
# 3              0.784              0.776             0.8025              0.793
# 4              0.784              0.776             0.8025              0.793
#
#    split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0             0.7795            0.787        0.009618                1
# 1             0.7795            0.787        0.009618                1
# 2             0.7795            0.787        0.009618                1
# 3             0.7795            0.787        0.009618                1
# 4             0.7795            0.787        0.009618                1

# %%
#Nested cross validate
from sklearn.model_selection import cross_val_score

scores = cross_val_score(busca, x_azar, y_azar, cv = KFold(n_splits=10, shuffle = True), groups = dados.modelo)
scores
# Out:
# array([0.805, 0.774, 0.781, 0.784, 0.789, 0.794, 0.785, 0.756, 0.811,
#        0.788])

# %%
def imprime_score(scores):
  media = scores.mean() * 100
  desvio = scores.std() * 100
  print("Accuracy médio %.2f" % media)
  print("Intervalo [%.2f, %.2f]" % (media - 2 * desvio, media + 2 * desvio))

# %%
imprime_score(scores)
# Out:
# Accuracy médio 78.67
# Intervalo [75.75, 81.59]

# %%
melhor = busca.best_estimator_
print(melhor)
# Out:
# DecisionTreeClassifier(max_depth=3, min_samples_leaf=32, min_samples_split=32)

# %%
from sklearn.tree import export_graphviz
import graphviz

features = x_azar.columns
dot_data = export_graphviz(melhor, out_file=None, filled=True, rounded=True, class_names=["não", "sim"], feature_names = features)

graph = graphviz.Source(dot_data)
graph

# %%
from sklearn.model_selection import RandomizedSearchCV

SEED=301
np.random.seed(SEED)

espaco_de_parametros = {
    "max_depth" : [3, 5],
    "min_samples_split" : [32, 64, 128],
    "min_samples_leaf" : [32, 64, 128],
    "criterion" : ["gini", "entropy"]
}

busca = RandomizedSearchCV(DecisionTreeClassifier(),
                    espaco_de_parametros,
                    cv = KFold(n_splits = 5, shuffle=True), random_state = SEED, n_iter = 16)
busca.fit(x_azar, y_azar)
resultados = pd.DataFrame(busca.cv_results_)
resultados.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.014342      0.001048         0.002584        0.000074
# 1       0.011173      0.001842         0.002952        0.000765
# 2       0.010418      0.000499         0.002471        0.000076
# 3       0.016389      0.000109         0.002492        0.000042
# 4       0.016993      0.000887         0.002555        0.000043
#
#   param_min_samples_split param_min_samples_leaf param_max_depth  \
# 0                     128                    128               5
# 1                      64                     32               3
# 2                      64                    128               3
# 3                      32                     64               5
# 4                      64                     64               5
#
#   param_criterion                                             params  \
# 0            gini  {'min_samples_split': 128, 'min_samples_leaf':...
# 1            gini  {'min_samples_split': 64, 'min_samples_leaf': ...
# 2            gini  {'min_samples_split': 64, 'min_samples_leaf': ...
# 3         entropy  {'min_samples_split': 32, 'min_samples_leaf': ...
# 4         entropy  {'min_samples_split': 64, 'min_samples_leaf': ...
#
#    split0_test_score  split1_test_score  split2_test_score  split3_test_score  \
# 0              0.784              0.769             0.7985              0.793
# 1              0.784              0.776             0.8025              0.793
# 2              0.784              0.776             0.8025              0.793
# 3              0.784              0.769             0.8005              0.793
# 4              0.784              0.769             0.8005              0.793
#
#    split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0             0.7730           0.7835        0.011278               13
# 1             0.7795           0.7870        0.009618                1
# 2             0.7795           0.7870        0.009618                1
# 3             0.7730           0.7839        0.011825                7
# 4             0.7730           0.7839        0.011825                7

# %%
scores = cross_val_score(busca, x_azar, y_azar, cv = KFold(n_splits=5, shuffle=True))
imprime_score(scores)
# Out:
# Accuracy médio 78.71
# Intervalo [77.49, 79.93]

# %%
melhor = busca.best_estimator_
print(melhor)
# Out:
# DecisionTreeClassifier(max_depth=3, min_samples_leaf=32, min_samples_split=64)

# %%
dot_data = export_graphviz(modelo, out_file=None, filled=True, rounded=True, class_names=["não", "sim"], feature_names = features)

graph = graphviz.Source(dot_data)
graph

# %%
from scipy.stats import randint
SEED=301
np.random.seed(SEED)

espaco_de_parametros = {
    "max_depth" : [3, 5, 10, 15, 20, 30, None],
    "min_samples_split" : randint(32,128),
    "min_samples_leaf" : randint(32,128),
    "criterion" : ["gini", "entropy"]
}

busca = RandomizedSearchCV(DecisionTreeClassifier(),
                    espaco_de_parametros,
                    cv = KFold(n_splits = 5, shuffle=True), random_state = SEED, n_iter = 16)
busca.fit(x_azar, y_azar)
resultados = pd.DataFrame(busca.cv_results_)
resultados.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.019008      0.001499         0.004885        0.001388
# 1       0.026097      0.001342         0.004156        0.000255
# 2       0.023064      0.000774         0.004325        0.000145
# 3       0.033827      0.002970         0.004308        0.000208
# 4       0.029167      0.009395         0.004028        0.000135
#
#   param_criterion param_max_depth param_min_samples_leaf  \
# 0         entropy               3                     71
# 1            gini              15                     93
# 2            gini              20                    124
# 3            gini            None                     46
# 4            gini              15                    126
#
#   param_min_samples_split                                             params  \
# 0                     100  {'criterion': 'entropy', 'max_depth': 3, 'min_...
# 1                     111  {'criterion': 'gini', 'max_depth': 15, 'min_sa...
# 2                      88  {'criterion': 'gini', 'max_depth': 20, 'min_sa...
# 3                      62  {'criterion': 'gini', 'max_depth': None, 'min_...
# 4                      84  {'criterion': 'gini', 'max_depth': 15, 'min_sa...
#
#    split0_test_score  split1_test_score  split2_test_score  split3_test_score  \
# 0             0.7840             0.7760             0.8025             0.7930
# 1             0.7740             0.7725             0.7830             0.7805
# 2             0.7705             0.7745             0.7990             0.7790
# 3             0.7575             0.7730             0.7725             0.7835
# 4             0.7705             0.7735             0.7995             0.7790
#
#    split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0             0.7795           0.7870        0.009618                1
# 1             0.7725           0.7765        0.004393               14
# 2             0.7735           0.7793        0.010221                8
# 3             0.7560           0.7685        0.010378               16
# 4             0.7745           0.7794        0.010413                7

# %%
scores = cross_val_score(busca, x_azar, y_azar, cv = KFold(n_splits=5, shuffle=True))
imprime_score(scores)
melhor = busca.best_estimator_
print(melhor)
# Out:
# Accuracy médio 78.71
# Intervalo [77.49, 79.93]
# DecisionTreeClassifier(criterion='entropy', max_depth=3, min_samples_leaf=71,
#                        min_samples_split=100)

# %%
resultados_ordenados_por_media = resultados.sort_values("mean_test_score", ascending = False)
for indice, linha in resultados_ordenados_por_media.iterrows():
  print("%.3f +-(%.3f) %s" % (linha.mean_test_score, linha.std_test_score * 2, linha.params))
# Out:
# 0.787 +-(0.019) {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 71, 'min_samples_split': 100}
# 0.784 +-(0.024) {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 73, 'min_samples_split': 72}
# 0.784 +-(0.024) {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 64, 'min_samples_split': 67}
# 0.781 +-(0.017) {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 108, 'min_samples_split': 110}
# 0.780 +-(0.019) {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 125, 'min_samples_split': 59}
# 0.780 +-(0.012) {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 103, 'min_samples_split': 96}
# 0.779 +-(0.021) {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 126, 'min_samples_split': 84}
# 0.779 +-(0.020) {'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 124, 'min_samples_split': 88}
# 0.779 +-(0.009) {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 101, 'min_samples_split': 52}
# 0.779 +-(0.014) {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 104, 'min_samples_split': 88}
# 0.779 +-(0.010) {'criterion': 'gini', 'max_depth': 30, 'min_samples_leaf': 100, 'min_samples_split': 84}
# 0.778 +-(0.014) {'criterion': 'entropy', 'max_depth': 30, 'min_samples_leaf': 74, 'min_samples_split': 58}
# 0.777 +-(0.013) {'criterion': 'gini', 'max_depth': 30, 'min_samples_leaf': 88, 'min_samples_split': 78}
# 0.776 +-(0.009) {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 93, 'min_samples_split': 111}
# 0.775 +-(0.015) {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 52, 'min_samples_split': 80}
# 0.769 +-(0.021) {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 46, 'min_samples_split': 62}

# %%
from scipy.stats import randint
SEED=301
np.random.seed(SEED)

espaco_de_parametros = {
    "max_depth" : [3, 5, 10, 15, 20, 30, None],
    "min_samples_split" : randint(32,128),
    "min_samples_leaf" : randint(32,128),
    "criterion" : ["gini", "entropy"]
}

busca = RandomizedSearchCV(DecisionTreeClassifier(),
                    espaco_de_parametros,
                    cv = KFold(n_splits = 5, shuffle=True), random_state = SEED, n_iter = 64)
busca.fit(x_azar, y_azar)
resultados = pd.DataFrame(busca.cv_results_)
resultados.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.019868      0.002187         0.004310        0.000207
# 1       0.030908      0.005304         0.004372        0.000308
# 2       0.029346      0.007952         0.004374        0.000324
# 3       0.033923      0.004278         0.006390        0.002352
# 4       0.026618      0.003483         0.004580        0.000189
#
#   param_criterion param_max_depth param_min_samples_leaf  \
# 0         entropy               3                     71
# 1            gini              15                     93
# 2            gini              20                    124
# 3            gini            None                     46
# 4            gini              15                    126
#
#   param_min_samples_split                                             params  \
# 0                     100  {'criterion': 'entropy', 'max_depth': 3, 'min_...
# 1                     111  {'criterion': 'gini', 'max_depth': 15, 'min_sa...
# 2                      88  {'criterion': 'gini', 'max_depth': 20, 'min_sa...
# 3                      62  {'criterion': 'gini', 'max_depth': None, 'min_...
# 4                      84  {'criterion': 'gini', 'max_depth': 15, 'min_sa...
#
#    split0_test_score  split1_test_score  split2_test_score  split3_test_score  \
# 0             0.7840             0.7760             0.8025             0.7930
# 1             0.7740             0.7725             0.7830             0.7805
# 2             0.7705             0.7745             0.7990             0.7790
# 3             0.7575             0.7730             0.7725             0.7835
# 4             0.7705             0.7735             0.7995             0.7790
#
#    split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0             0.7795           0.7870        0.009618                1
# 1             0.7725           0.7765        0.004393               46
# 2             0.7735           0.7793        0.010221               27
# 3             0.7560           0.7685        0.010378               64
# 4             0.7745           0.7794        0.010413               26

# %%
resultados_ordenados_por_media = resultados.sort_values("mean_test_score", ascending = False)
for indice, linha in resultados_ordenados_por_media.iterrows():
  print("%.3f +-(%.3f) %s" % (linha.mean_test_score, linha.std_test_score * 2, linha.params))
# Out:
# 0.787 +-(0.019) {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 71, 'min_samples_split': 100}
# 0.787 +-(0.019) {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 69, 'min_samples_split': 124}
# 0.787 +-(0.019) {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 63, 'min_samples_split': 88}
# 0.787 +-(0.019) {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 67, 'min_samples_split': 76}
# 0.787 +-(0.019) {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 65, 'min_samples_split': 50}
# 0.787 +-(0.019) {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 120, 'min_samples_split': 46}
# 0.787 +-(0.019) {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 53, 'min_samples_split': 111}
# 0.787 +-(0.019) {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 106, 'min_samples_split': 108}
# 0.784 +-(0.024) {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 64, 'min_samples_split': 67}
# 0.784 +-(0.024) {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 56, 'min_samples_split': 54}
# 0.784 +-(0.024) {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 45, 'min_samples_split': 103}
# 0.784 +-(0.024) {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 101, 'min_samples_split': 95}
# 0.784 +-(0.024) {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 79, 'min_samples_split': 117}
# 0.784 +-(0.024) {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 73, 'min_samples_split': 72}
# 0.783 +-(0.023) {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 111, 'min_samples_split': 94}
# 0.781 +-(0.017) {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 108, 'min_samples_split': 110}
# 0.781 +-(0.017) {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 107, 'min_samples_split': 88}
# 0.781 +-(0.017) {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 104, 'min_samples_split': 62}
# 0.781 +-(0.016) {'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 107, 'min_samples_split': 77}
# 0.780 +-(0.019) {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 125, 'min_samples_split': 124}
# 0.780 +-(0.019) {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 125, 'min_samples_split': 59}
# 0.780 +-(0.013) {'criterion': 'gini', 'max_depth': 30, 'min_samples_leaf': 101, 'min_samples_split': 113}
# 0.780 +-(0.012) {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 103, 'min_samples_split': 96}
# 0.780 +-(0.015) {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 102, 'min_samples_split': 59}
# 0.780 +-(0.012) {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 106, 'min_samples_split': 66}
# 0.779 +-(0.021) {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 126, 'min_samples_split': 84}
# 0.779 +-(0.020) {'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 124, 'min_samples_split': 88}
# 0.779 +-(0.009) {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 101, 'min_samples_split': 52}
# 0.779 +-(0.014) {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 104, 'min_samples_split': 88}
# 0.779 +-(0.019) {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 120, 'min_samples_split': 68}
# 0.779 +-(0.021) {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 123, 'min_samples_split': 91}
# 0.779 +-(0.010) {'criterion': 'gini', 'max_depth': 30, 'min_samples_leaf': 100, 'min_samples_split': 84}
# 0.779 +-(0.012) {'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 76, 'min_samples_split': 102}
# 0.779 +-(0.012) {'criterion': 'gini', 'max_depth': 30, 'min_samples_leaf': 76, 'min_samples_split': 124}
# 0.779 +-(0.020) {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 121, 'min_samples_split': 84}
# 0.779 +-(0.020) {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 121, 'min_samples_split': 47}
# 0.778 +-(0.011) {'criterion': 'entropy', 'max_depth': 30, 'min_samples_leaf': 100, 'min_samples_split': 51}
# 0.778 +-(0.014) {'criterion': 'entropy', 'max_depth': 30, 'min_samples_leaf': 74, 'min_samples_split': 58}
# 0.778 +-(0.011) {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 49, 'min_samples_split': 126}
# 0.778 +-(0.012) {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 95, 'min_samples_split': 112}
# 0.778 +-(0.012) {'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 94, 'min_samples_split': 65}
# 0.777 +-(0.012) {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 92, 'min_samples_split': 91}
# 0.777 +-(0.015) {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 70, 'min_samples_split': 86}
# 0.777 +-(0.013) {'criterion': 'gini', 'max_depth': 30, 'min_samples_leaf': 88, 'min_samples_split': 78}
# 0.777 +-(0.009) {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 93, 'min_samples_split': 117}
# 0.776 +-(0.009) {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 93, 'min_samples_split': 111}
# 0.776 +-(0.008) {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 92, 'min_samples_split': 54}
# 0.776 +-(0.014) {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 64, 'min_samples_split': 72}
# 0.776 +-(0.015) {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 55, 'min_samples_split': 36}
# 0.775 +-(0.015) {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 52, 'min_samples_split': 80}
# 0.775 +-(0.022) {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 46, 'min_samples_split': 83}
# 0.774 +-(0.015) {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 51, 'min_samples_split': 100}
# 0.774 +-(0.015) {'criterion': 'gini', 'max_depth': 30, 'min_samples_leaf': 63, 'min_samples_split': 121}
# 0.773 +-(0.016) {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 37, 'min_samples_split': 120}
# 0.773 +-(0.015) {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 39, 'min_samples_split': 68}
# 0.773 +-(0.017) {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 42, 'min_samples_split': 92}
# 0.771 +-(0.017) {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 47, 'min_samples_split': 43}
# 0.770 +-(0.019) {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 33, 'min_samples_split': 72}
# 0.770 +-(0.019) {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 38, 'min_samples_split': 106}
# 0.770 +-(0.017) {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 38, 'min_samples_split': 43}
# 0.770 +-(0.015) {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 43, 'min_samples_split': 78}
# 0.769 +-(0.019) {'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 37, 'min_samples_split': 35}
# 0.769 +-(0.016) {'criterion': 'entropy', 'max_depth': 30, 'min_samples_leaf': 42, 'min_samples_split': 70}
# 0.769 +-(0.021) {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 46, 'min_samples_split': 62}

# %%
scores = cross_val_score(busca, x_azar, y_azar, cv = KFold(n_splits=5, shuffle=True))
imprime_score(scores)
melhor = busca.best_estimator_
print(melhor)
# Out:
# Accuracy médio 78.66
# Intervalo [76.79, 80.53]
# DecisionTreeClassifier(criterion='entropy', max_depth=3, min_samples_leaf=71,
#                        min_samples_split=100)

# %%
#Comparando GridSearchCV vs RandomizedSearch
from sklearn.ensemble import RandomForestClassifier
import time
SEED=301
np.random.seed(SEED)

espaco_de_parametros = {
    "n_estimators" : [10, 100],
    "max_depth" : [3, 5],
    "min_samples_split": [32, 64, 128],
    "min_samples_leaf": [32, 64, 128],
    "criterion": ["gini", "entropy"],
    "bootstrap" : [True, False]
}


tic = time.time()
busca = GridSearchCV(RandomForestClassifier(),
                    espaco_de_parametros,
                    cv = KFold(n_splits = 5, shuffle=True))
busca.fit(x_azar, y_azar)
tac = time.time()
tempo_passado = tac - tic
print(f"Tempo passado ao rodar o modelo: {tempo_passado}")

resultados = pd.DataFrame(busca.cv_results_)
resultados.head()
# Out:
# Tempo passado ao rodar o modelo: 239.712069272995
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.084182      0.013211         0.009328        0.002783
# 1       0.691135      0.027865         0.035645        0.001882
# 2       0.072372      0.002255         0.007644        0.000308
# 3       0.462476      0.099388         0.024014        0.003393
# 4       0.045557      0.005181         0.004928        0.000235
#
#   param_bootstrap param_criterion param_max_depth param_min_samples_leaf  \
# 0            True            gini               3                     32
# 1            True            gini               3                     32
# 2            True            gini               3                     32
# 3            True            gini               3                     32
# 4            True            gini               3                     32
#
#   param_min_samples_split param_n_estimators  \
# 0                      32                 10
# 1                      32                100
# 2                      64                 10
# 3                      64                100
# 4                     128                 10
#
#                                               params  split0_test_score  \
# 0  {'bootstrap': True, 'criterion': 'gini', 'max_...             0.7745
# 1  {'bootstrap': True, 'criterion': 'gini', 'max_...             0.7655
# 2  {'bootstrap': True, 'criterion': 'gini', 'max_...             0.7780
# 3  {'bootstrap': True, 'criterion': 'gini', 'max_...             0.7425
# 4  {'bootstrap': True, 'criterion': 'gini', 'max_...             0.7755
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0             0.7560             0.7490             0.7850             0.7450
# 1             0.7555             0.7945             0.7850             0.7625
# 2             0.7635             0.7835             0.7845             0.7560
# 3             0.7550             0.7950             0.7850             0.7620
# 4             0.7405             0.7485             0.7760             0.7630
#
#    mean_test_score  std_test_score  rank_test_score
# 0           0.7619        0.015357              130
# 1           0.7726        0.014685               93
# 2           0.7731        0.011373               89
# 3           0.7679        0.019356              119
# 4           0.7607        0.014250              135

# %%
resultados_ordenados_por_media = resultados.sort_values("mean_test_score", ascending = False)
for indice, linha in resultados_ordenados_por_media[:5].iterrows():
  print("%.3f +-(%.3f) %s" % (linha.mean_test_score, linha.std_test_score * 2, linha.params))
# Out:
# 0.780 +-(0.020) {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 32, 'min_samples_split': 64, 'n_estimators': 10}
# 0.778 +-(0.020) {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 32, 'min_samples_split': 128, 'n_estimators': 10}
# 0.778 +-(0.030) {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 64, 'min_samples_split': 64, 'n_estimators': 10}
# 0.778 +-(0.027) {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 64, 'min_samples_split': 64, 'n_estimators': 10}
# 0.778 +-(0.033) {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 64, 'min_samples_split': 64, 'n_estimators': 100}

# %%
#Tempo demais, da erro no Colab
tic = time.time()
scores = cross_val_score(busca, x_azar, y_azar, cv = KFold(n_splits=5, shuffle=True))
tac = time.time()
tempo_passado = tac - tic
print(f"Tempo passado ao rodar o modelo: {tempo_passado}")
imprime_score(scores)
melhor = busca.best_estimator_
print(melhor)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-61-84ed04551a2b> in <cell line: 2>()
#       1 tic = time.time()
# ----> 2 scores = cross_val_score(busca, x_azar, y_azar, cv = KFold(n_splits=5, shuffle=True))
#       3 tac = time.time()
#       4 tempo_passado = tac - tic
#       5 print(f"Tempo passado ao rodar o modelo: {tempo_passado}")
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     513     scorer = check_scoring(estimator, scoring=scoring)
#     514
# --> 515     cv_results = cross_validate(
#     516         estimator=estimator,
#     517         X=X,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     264     # independent, and that it is pickle-able.
#     265     parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 266     results = parallel(
#     267         delayed(_fit_and_score)(
#     268             clone(estimator),
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py in __call__(self, iterable)
#      61             for delayed_func, args, kwargs in iterable
#      62         )
# ---> 63         return super().__call__(iterable_with_config)
#      64
#      65
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1916             output = self._get_sequential_output(iterable)
#    1917             next(output)
# -> 1918             return output if self.return_generator else list(output)
#    1919
#    1920         # Let's create an ID that uniquely identifies the current call. If the
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in _get_sequential_output(self, iterable)
#    1845                 self.n_dispatched_batches += 1
#    1846                 self.n_dispatched_tasks += 1
# -> 1847                 res = func(*args, **kwargs)
#    1848                 self.n_completed_tasks += 1
#    1849                 self.print_progress()
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py in __call__(self, *args, **kwargs)
#     121             config = {}
#     122         with config_context(**config):
# --> 123             return self.function(*args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     684             estimator.fit(X_train, **fit_params)
#     685         else:
# --> 686             estimator.fit(X_train, y_train, **fit_params)
#     687
#     688     except Exception:
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     872                 return results
#     873
# --> 874             self._run_search(evaluate_candidates)
#     875
#     876             # multimetric is determined here because in the case of a callable
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1386     def _run_search(self, evaluate_candidates):
#    1387         """Search all candidates in param_grid"""
# -> 1388         evaluate_candidates(ParameterGrid(self.param_grid))
#    1389
#    1390
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     819                     )
#     820
# --> 821                 out = parallel(
#     822                     delayed(_fit_and_score)(
#     823                         clone(base_estimator),
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py in __call__(self, iterable)
#      61             for delayed_func, args, kwargs in iterable
#      62         )
# ---> 63         return super().__call__(iterable_with_config)
#      64
#      65
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1916             output = self._get_sequential_output(iterable)
#    1917             next(output)
# -> 1918             return output if self.return_generator else list(output)
#    1919
#    1920         # Let's create an ID that uniquely identifies the current call. If the
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in _get_sequential_output(self, iterable)
#    1845                 self.n_dispatched_batches += 1
#    1846                 self.n_dispatched_tasks += 1
# -> 1847                 res = func(*args, **kwargs)
#    1848                 self.n_completed_tasks += 1
#    1849                 self.print_progress()
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py in __call__(self, *args, **kwargs)
#     121             config = {}
#     122         with config_context(**config):
# --> 123             return self.function(*args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     684             estimator.fit(X_train, **fit_params)
#     685         else:
# --> 686             estimator.fit(X_train, y_train, **fit_params)
#     687
#     688     except Exception:
#
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     471             # parallel_backend contexts set at a higher level,
#     472             # since correctness does not rely on using threads.
# --> 473             trees = Parallel(
#     474                 n_jobs=self.n_jobs,
#     475                 verbose=self.verbose,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py in __call__(self, iterable)
#      61             for delayed_func, args, kwargs in iterable
#      62         )
# ---> 63         return super().__call__(iterable_with_config)
#      64
#      65
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1916             output = self._get_sequential_output(iterable)
#    1917             next(output)
# -> 1918             return output if self.return_generator else list(output)
#    1919
#    1920         # Let's create an ID that uniquely identifies the current call. If the
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in _get_sequential_output(self, iterable)
#    1845                 self.n_dispatched_batches += 1
#    1846                 self.n_dispatched_tasks += 1
# -> 1847                 res = func(*args, **kwargs)
#    1848                 self.n_completed_tasks += 1
#    1849                 self.print_progress()
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py in __call__(self, *args, **kwargs)
#     121             config = {}
#     122         with config_context(**config):
# --> 123             return self.function(*args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py in _parallel_build_trees(tree, bootstrap, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     169             curr_sample_weight = sample_weight.copy()
#     170
# --> 171         indices = _generate_sample_indices(
#     172             tree.random_state, n_samples, n_samples_bootstrap
#     173         )
#
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py in _generate_sample_indices(random_state, n_samples, n_samples_bootstrap)
#     125     Private function used to _parallel_build_trees function."""
#     126
# --> 127     random_instance = check_random_state(random_state)
#     128     sample_indices = random_instance.randint(0, n_samples, n_samples_bootstrap)
#     129
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_random_state(seed)
#    1224         return np.random.mtrand._rand
#    1225     if isinstance(seed, numbers.Integral):
# -> 1226         return np.random.RandomState(seed)
#    1227     if isinstance(seed, np.random.RandomState):
#    1228         return seed
#
# mtrand.pyx in numpy.random.mtrand.RandomState.__init__()
#
# _mt19937.pyx in numpy.random._mt19937.MT19937.__init__()
#
# /usr/lib/python3.10/contextlib.py in inner(*args, **kwds)
#      77         def inner(*args, **kwds):
#      78             with self._recreate_cm():
# ---> 79                 return func(*args, **kwds)
#      80         return inner
#      81
#
# KeyboardInterrupt:

# %%
SEED=301
np.random.seed(SEED)

espaco_de_parametros = {
    "n_estimators" : [10, 100],
    "max_depth" : [3, 5],
    "min_samples_split": [32, 64, 128],
    "min_samples_leaf": [32, 64, 128],
    "criterion": ["gini", "entropy"],
    "bootstrap" : [True, False]
}


tic = time.time()
busca = RandomizedSearchCV(RandomForestClassifier(),
                    espaco_de_parametros,
                    n_iter = 20,
                    cv = KFold(n_splits = 5, shuffle=True))
busca.fit(x_azar, y_azar)
tac = time.time()
tempo_passado = tac - tic
print(f"Tempo passado ao rodar o modelo: {tempo_passado}")

resultados = pd.DataFrame(busca.cv_results_)
resultados.head()
# Out:
# Tempo passado ao rodar o modelo: 35.09265160560608
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.715448      0.023901         0.034876        0.005059
# 1       0.060543      0.006264         0.005381        0.000661
# 2       0.735349      0.122761         0.028532        0.002808
# 3       0.041911      0.001063         0.004842        0.000500
# 4       0.054394      0.002620         0.005433        0.000986
#
#   param_n_estimators param_min_samples_split param_min_samples_leaf  \
# 0                100                      32                    128
# 1                 10                      32                    128
# 2                100                      32                     32
# 3                 10                     128                     32
# 4                 10                      64                     32
#
#   param_max_depth param_criterion param_bootstrap  \
# 0               3         entropy            True
# 1               5         entropy            True
# 2               5         entropy            True
# 3               3            gini            True
# 4               3         entropy           False
#
#                                               params  split0_test_score  \
# 0  {'n_estimators': 100, 'min_samples_split': 32,...              0.771
# 1  {'n_estimators': 10, 'min_samples_split': 32, ...              0.750
# 2  {'n_estimators': 100, 'min_samples_split': 32,...              0.771
# 3  {'n_estimators': 10, 'min_samples_split': 128,...              0.750
# 4  {'n_estimators': 10, 'min_samples_split': 64, ...              0.771
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0             0.7740             0.7925             0.7775             0.7560
# 1             0.7785             0.7820             0.7785             0.7645
# 2             0.7745             0.7930             0.7785             0.7585
# 3             0.7600             0.7450             0.7390             0.7520
# 4             0.7740             0.7635             0.7370             0.7585
#
#    mean_test_score  std_test_score  rank_test_score
# 0           0.7742        0.011724               10
# 1           0.7707        0.011969               13
# 2           0.7751        0.011178                6
# 3           0.7492        0.007026               20
# 4           0.7608        0.013094               18

# %%
resultados_ordenados_por_media = resultados.sort_values("mean_test_score", ascending = False)
for indice, linha in resultados_ordenados_por_media[:5].iterrows():
  print("%.3f +-(%.3f) %s" % (linha.mean_test_score, linha.std_test_score * 2, linha.params))
# Out:
# 0.776 +-(0.025) {'n_estimators': 100, 'min_samples_split': 32, 'min_samples_leaf': 32, 'max_depth': 5, 'criterion': 'gini', 'bootstrap': False}
# 0.776 +-(0.023) {'n_estimators': 100, 'min_samples_split': 32, 'min_samples_leaf': 128, 'max_depth': 3, 'criterion': 'gini', 'bootstrap': False}
# 0.776 +-(0.024) {'n_estimators': 100, 'min_samples_split': 64, 'min_samples_leaf': 32, 'max_depth': 5, 'criterion': 'entropy', 'bootstrap': True}
# 0.776 +-(0.032) {'n_estimators': 10, 'min_samples_split': 32, 'min_samples_leaf': 64, 'max_depth': 3, 'criterion': 'entropy', 'bootstrap': False}
# 0.775 +-(0.035) {'n_estimators': 10, 'min_samples_split': 32, 'min_samples_leaf': 32, 'max_depth': 5, 'criterion': 'gini', 'bootstrap': True}

# %%
tic = time.time()
scores = cross_val_score(busca, x_azar, y_azar, cv = KFold(n_splits=5, shuffle=True))
tac = time.time()
tempo_passado = tac - tic
print(f"Tempo passado ao rodar o modelo: {tempo_passado}")
imprime_score(scores)
melhor = busca.best_estimator_
print(melhor)
# Out:
# Tempo passado ao rodar o modelo: 152.9601366519928
# Accuracy médio 77.59
# Intervalo [76.47, 78.71]
# RandomForestClassifier(bootstrap=False, max_depth=5, min_samples_leaf=32,
#                        min_samples_split=32)

# %%
SEED=301
np.random.seed(SEED)

espaco_de_parametros = {
    "n_estimators" : randint(10,101),
    "max_depth" : randint(3, 6),
    "min_samples_split": randint(32,129),
    "min_samples_leaf": randint(32,129),
    "criterion": ["gini", "entropy"],
    "bootstrap" : [True, False]
}


tic = time.time()
busca = RandomizedSearchCV(RandomForestClassifier(),
                    espaco_de_parametros,
                    n_iter = 80,
                    cv = KFold(n_splits = 5, shuffle=True))
busca.fit(x_azar, y_azar)
tac = time.time()
tempo_passado = tac - tic
print(f"Tempo passado ao rodar o modelo: {tempo_passado}")

resultados = pd.DataFrame(busca.cv_results_)
resultados.head()
# Out:
# Tempo passado ao rodar o modelo: 127.70509743690491
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.838149      0.213188         0.036005        0.007478
# 1       0.973638      0.255421         0.037604        0.013037
# 2       0.572703      0.019503         0.033034        0.005309
# 3       0.330696      0.012165         0.022285        0.006487
# 4       0.550535      0.125456         0.034772        0.013398
#
#   param_bootstrap param_criterion param_max_depth param_min_samples_leaf  \
# 0           False            gini               3                     50
# 1            True            gini               3                     88
# 2            True            gini               3                    126
# 3            True            gini               3                     57
# 4            True            gini               4                     52
#
#   param_min_samples_split param_n_estimators  \
# 0                      93                 89
# 1                     104                 80
# 2                      84                 77
# 3                      73                 50
# 4                      88                 68
#
#                                               params  split0_test_score  \
# 0  {'bootstrap': False, 'criterion': 'gini', 'max...             0.7715
# 1  {'bootstrap': True, 'criterion': 'gini', 'max_...             0.7715
# 2  {'bootstrap': True, 'criterion': 'gini', 'max_...             0.7685
# 3  {'bootstrap': True, 'criterion': 'gini', 'max_...             0.7720
# 4  {'bootstrap': True, 'criterion': 'gini', 'max_...             0.7720
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0             0.7620             0.7750             0.7855             0.7580
# 1             0.7575             0.7925             0.7855             0.7575
# 2             0.7695             0.7925             0.7795             0.7575
# 3             0.7670             0.7830             0.7865             0.7580
# 4             0.7685             0.7930             0.7850             0.7585
#
#    mean_test_score  std_test_score  rank_test_score
# 0           0.7704        0.009744               75
# 1           0.7729        0.014277               63
# 2           0.7735        0.011781               59
# 3           0.7733        0.010429               60
# 4           0.7754        0.012220               30

# %%
resultados_ordenados_por_media = resultados.sort_values("mean_test_score", ascending = False)
for indice, linha in resultados_ordenados_por_media[:5].iterrows():
  print("%.3f +-(%.3f) %s" % (linha.mean_test_score, linha.std_test_score * 2, linha.params))
# Out:
# 0.779 +-(0.025) {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 84, 'min_samples_split': 89, 'n_estimators': 48}
# 0.778 +-(0.031) {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 32, 'min_samples_split': 96, 'n_estimators': 18}
# 0.778 +-(0.032) {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 121, 'min_samples_split': 47, 'n_estimators': 27}
# 0.778 +-(0.024) {'bootstrap': False, 'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 96, 'min_samples_split': 98, 'n_estimators': 11}
# 0.777 +-(0.029) {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 63, 'min_samples_split': 88, 'n_estimators': 69}

# %%
# 0.6 treino
# 0.2 teste
# 0.2 validacao
from sklearn.model_selection import train_test_split

SEED=301
np.random.seed(SEED)

x_treino_teste, x_validacao, y_treino_teste, y_validacao = train_test_split(x_azar, y_azar, test_size=0.2, shuffle=True, stratify=y_azar)
print(x_treino_teste.shape)
print(x_validacao.shape)
print(y_treino_teste.shape)
print(y_validacao.shape)
# Out:
# (8000, 3)
# (2000, 3)
# (8000,)
# (2000,)

# %%
# Se não usar cross Validation
from sklearn.model_selection import StratifiedShuffleSplit

split = StratifiedShuffleSplit(n_splits = 1, test_size = 0.25)
SEED=301
np.random.seed(SEED)

espaco_de_parametros = {
    "n_estimators" : randint(10,101),
    "max_depth" : randint(3, 6),
    "min_samples_split": randint(32,129),
    "min_samples_leaf": randint(32,129),
    "criterion": ["gini", "entropy"],
    "bootstrap" : [True, False]
}


tic = time.time()
busca = RandomizedSearchCV(RandomForestClassifier(),
                    espaco_de_parametros,
                    n_iter = 5,
                    cv = split)
busca.fit(x_treino_teste, y_treino_teste)
tac = time.time()
tempo_passado = tac - tic
print(f"Tempo passado ao rodar o modelo: {tempo_passado}")

resultados = pd.DataFrame(busca.cv_results_)
resultados.head()
# Out:
# Tempo passado ao rodar o modelo: 1.826080560684204
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.375888           0.0         0.021186             0.0
# 1       0.329825           0.0         0.024141             0.0
# 2       0.286630           0.0         0.021044             0.0
# 3       0.196124           0.0         0.016839             0.0
# 4       0.292015           0.0         0.017102             0.0
#
#   param_bootstrap param_criterion param_max_depth param_min_samples_leaf  \
# 0           False            gini               3                     50
# 1            True            gini               3                     88
# 2            True            gini               3                    126
# 3            True            gini               3                     57
# 4            True            gini               4                     52
#
#   param_min_samples_split param_n_estimators  \
# 0                      93                 89
# 1                     104                 80
# 2                      84                 77
# 3                      73                 50
# 4                      88                 68
#
#                                               params  split0_test_score  \
# 0  {'bootstrap': False, 'criterion': 'gini', 'max...             0.7745
# 1  {'bootstrap': True, 'criterion': 'gini', 'max_...             0.7735
# 2  {'bootstrap': True, 'criterion': 'gini', 'max_...             0.7745
# 3  {'bootstrap': True, 'criterion': 'gini', 'max_...             0.7750
# 4  {'bootstrap': True, 'criterion': 'gini', 'max_...             0.7745
#
#    mean_test_score  std_test_score  rank_test_score
# 0           0.7745             0.0                2
# 1           0.7735             0.0                5
# 2           0.7745             0.0                2
# 3           0.7750             0.0                1
# 4           0.7745             0.0                2

# %%
tic = time.time()
scores = cross_val_score(busca, x_validacao, y_validacao, cv = split)
tac = time.time()
tempo_passado = tac - tic
print(f"Tempo passado ao rodar o modelo: {tempo_passado}")
scores
imprime_score(scores)
melhor = busca.best_estimator_
print(melhor)
# Out:
# Tempo passado ao rodar o modelo: 1.447624683380127
# array([0.79])
